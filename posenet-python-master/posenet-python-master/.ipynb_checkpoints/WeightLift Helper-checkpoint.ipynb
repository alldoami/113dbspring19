# %%
import tensorflow as tf
print(tf.__version__)
import cv2
print(cv2.__version__)
import time
import os
import numpy as np
import posenet
# Out:
# c:\users\micha\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.4.0
# 3.4.5

# %%
def unit_vector(vector):
    """ Returns the unit vector of the vector.  """
    return vector / np.linalg.norm(vector)

def angle(v1, v2):
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    return 180*(np.arccos(np.clip(np.dot(v1_u, v2_u), -1.0, 1.0)))/np.pi

# %%
path_input = './exercises'
path_output = './exercises_output'
model_number = 1
scale_factor = 0.1
body_points = {'rightShoulder':None,'rightWrist':None,'rightElbow':None,'leftShoulder':None,'leftWrist':None,'leftElbow':None}

# %%
filenames = [f.path for f in os.scandir(path_input) if f.is_file() and f.path.endswith(('.png', '.jpg'))]
print(filenames)
start = time.time()
with tf.Session() as sess:
    model_cfg, model_outputs = posenet.load_model(model_number, sess)
    output_stride = model_cfg['output_stride']
    for f in filenames:
        print(f)
        input_image, draw_image, output_scale = posenet.read_imgfile(
            f, scale_factor=scale_factor, output_stride=output_stride)

        heatmaps_result, offsets_result, displacement_fwd_result, displacement_bwd_result = sess.run(
            model_outputs,
            feed_dict={'image:0': input_image}
        )

        pose_scores, keypoint_scores, keypoint_coords = posenet.decode_multiple_poses(
            heatmaps_result.squeeze(axis=0),
            offsets_result.squeeze(axis=0),
            displacement_fwd_result.squeeze(axis=0),
            displacement_bwd_result.squeeze(axis=0),
            output_stride=output_stride,
            max_pose_detections=10,
            min_pose_score=0.25)

        keypoint_coords *= output_scale


        draw_image = posenet.draw_skel_and_kp(
            draw_image, pose_scores, keypoint_scores, keypoint_coords,
            min_pose_score=0.25, min_part_score=0.25)

        cv2.imwrite(os.path.join(path_output, os.path.relpath(f, path_input)), draw_image)

        
        print("Results for image: %s" % f)
        for pi in range(len(pose_scores)):
            if pose_scores[pi] == 0.:
                break
            print('Pose #%d, score = %f' % (pi, pose_scores[pi]))
            for ki, (s, c) in enumerate(zip(keypoint_scores[pi, :], keypoint_coords[pi, :, :])):
                print('Keypoint %s, score = %f, coord = %s' % (posenet.PART_NAMES[ki], s, c))
                if posenet.PART_NAMES[ki] in body_points:
                    body_points[posenet.PART_NAMES[ki]] = c
        angle_right = angle((body_points['rightShoulder']-body_points['rightElbow']),(body_points['rightWrist']-body_points['rightElbow']))
        angle_left = angle((body_points['leftShoulder']-body_points['leftElbow']),(body_points['leftWrist']-body_points['leftElbow']))
        print('Angle Right: %f, Angle Left: %f' %(angle_right ,angle_left))
    print('Average FPS:', len(filenames) / (time.time() - start))
# Out:
# ['./exercises\\20190409_150726.jpg', './exercises\\20190409_150728.jpg', './exercises\\20190409_150732.jpg', './exercises\\20190409_150759.jpg', './exercises\\20190409_150801.jpg', './exercises\\IMG_5579.jpg', './exercises\\IMG_5580.jpg', './exercises\\IMG_5581.jpg', './exercises\\IMG_5582.jpg', './exercises\\IMG_5583.jpg', './exercises\\IMG_5584.jpg', './exercises\\IMG_5585.jpg', './exercises\\IMG_5586.jpg', './exercises\\IMG_5587.jpg', './exercises\\IMG_5588.jpg', './exercises\\IMG_5589.jpg', './exercises\\IMG_5590.jpg', './exercises\\IMG_5591.jpg', './exercises\\IMG_5592.jpg', './exercises\\IMG_5595.jpg', './exercises\\IMG_5596.jpg', './exercises\\IMG_5597.jpg', './exercises\\IMG_5598.jpg', './exercises\\IMG_5599.jpg', './exercises\\IMG_5600.jpg', './exercises\\IMG_5601.jpg', './exercises\\IMG_5603.jpg', './exercises\\IMG_5604.jpg']
# C:\Users\micha\Desktop\ML\posenet-python-master\posenet\converter\config.py:9: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(cfg_f)
# ./exercises\20190409_150726.jpg
# Results for image: ./exercises\20190409_150726.jpg
# Pose #0, score = 0.908674
# Keypoint nose, score = 0.998251, coord = [1163.60378648 1085.43139957]
# Keypoint leftEye, score = 0.996071, coord = [1111.77297652 1127.03009269]
# Keypoint rightEye, score = 0.998343, coord = [1121.2450388  1025.38316065]
# Keypoint leftEar, score = 0.717798, coord = [1159.43343283 1188.3413381 ]
# Keypoint rightEar, score = 0.764840, coord = [1175.93659391  963.88070583]
# Keypoint leftShoulder, score = 0.994067, coord = [1419.88366163 1324.37832897]
# Keypoint rightShoulder, score = 0.982453, coord = [1437.104201    831.05991008]
# Keypoint leftElbow, score = 0.968251, coord = [1468.32661076 1735.72147567]
# Keypoint rightElbow, score = 0.894133, coord = [1482.28556051  468.01115718]
# Keypoint leftWrist, score = 0.516874, coord = [1128.8766204  1729.05239659]
# Keypoint rightWrist, score = 0.862884, coord = [1155.42038778  399.38647868]
# Keypoint leftHip, score = 0.993135, coord = [2188.12323698 1242.58508119]
# Keypoint rightHip, score = 0.994802, coord = [2198.09236879  921.64990657]
# Keypoint leftKnee, score = 0.900507, coord = [2702.50166363 1295.54878433]
# Keypoint rightKnee, score = 0.968873, coord = [2717.496351    930.92499175]
# Keypoint leftAnkle, score = 0.938754, coord = [3219.05117912 1257.52248665]
# Keypoint rightAnkle, score = 0.957429, coord = [3171.7375317  904.2935072]
# Angle Right: 94.762946, Angle Left: 82.157814
# ./exercises\20190409_150728.jpg
# Results for image: ./exercises\20190409_150728.jpg
# Pose #0, score = 0.903994
# Keypoint nose, score = 0.998434, coord = [1164.96310109  985.49533303]
# Keypoint leftEye, score = 0.995979, coord = [1107.59533758 1034.04345764]
# Keypoint rightEye, score = 0.995317, coord = [1122.07345726  936.40565808]
# Keypoint leftEar, score = 0.765739, coord = [1159.46226235 1084.55251644]
# Keypoint rightEar, score = 0.850572, coord = [1164.74145706  867.51146346]
# Keypoint leftShoulder, score = 0.991863, coord = [1427.0764788  1228.31989585]
# Keypoint rightShoulder, score = 0.528035, coord = [1434.93577191  735.46881127]
# Keypoint leftElbow, score = 0.953188, coord = [1465.89325861 1654.5438974 ]
# Keypoint rightElbow, score = 0.932322, coord = [1464.36569906  372.2842846 ]
# Keypoint leftWrist, score = 0.889684, coord = [1124.20627225 1621.01831227]
# Keypoint rightWrist, score = 0.872176, coord = [1160.03987163  312.08070703]
# Keypoint leftHip, score = 0.997130, coord = [2186.31158462 1167.17145742]
# Keypoint rightHip, score = 0.874936, coord = [2197.45947616  814.22695496]
# Keypoint leftKnee, score = 0.963261, coord = [2676.51226403 1181.09063223]
# Keypoint rightKnee, score = 0.932091, coord = [2697.38723062  815.83640538]
# Keypoint leftAnkle, score = 0.940903, coord = [3225.88100945 1161.6013769 ]
# Keypoint rightAnkle, score = 0.886274, coord = [3165.76631579  822.06715365]
# Angle Right: 96.557389, Angle Left: 79.192552
# ./exercises\20190409_150732.jpg
# Results for image: ./exercises\20190409_150732.jpg
# Pose #0, score = 0.817925
# Keypoint nose, score = 0.999622, coord = [1554.04420239  979.99163066]
# Keypoint leftEye, score = 0.998676, coord = [1482.34383326 1038.51780827]
# Keypoint rightEye, score = 0.998542, coord = [1491.98983757  906.93623874]
# Keypoint leftEar, score = 0.740569, coord = [1529.66108616 1115.1094407 ]
# Keypoint rightEar, score = 0.850131, coord = [1566.30702883  808.84111248]
# Keypoint leftShoulder, score = 0.869136, coord = [1877.75268387 1273.36359785]
# Keypoint rightShoulder, score = 0.946177, coord = [1887.10404021  634.06696497]
# Keypoint leftElbow, score = 0.940677, coord = [1935.03903982 1802.41616956]
# Keypoint rightElbow, score = 0.952650, coord = [1909.8762871   169.62603139]
# Keypoint leftWrist, score = 0.846060, coord = [1520.68950472 1843.08037565]
# Keypoint rightWrist, score = 0.885429, coord = [1490.33074243  137.85254014]
# Keypoint leftHip, score = 0.964037, coord = [2903.82857738 1183.34033749]
# Keypoint rightHip, score = 0.864100, coord = [2896.9448577   735.44911686]
# Keypoint leftKnee, score = 0.928655, coord = [3605.74074617 1201.18087946]
# Keypoint rightKnee, score = 0.424394, coord = [3613.75673898  682.38489813]
# Keypoint leftAnkle, score = 0.321390, coord = [4094.63453678 1201.60420037]
# Keypoint rightAnkle, score = 0.374483, coord = [4083.18703014  663.34497395]
# Angle Right: 91.523869, Angle Left: 89.425083
# ./exercises\20190409_150759.jpg
# Results for image: ./exercises\20190409_150759.jpg
# Pose #0, score = 0.856348
# Keypoint nose, score = 0.998466, coord = [ 972.81960559 1045.6169587 ]
# Keypoint leftEye, score = 0.991550, coord = [ 920.1428244 1082.0609239]
# Keypoint rightEye, score = 0.998487, coord = [930.72629401 978.30773874]
# Keypoint leftEar, score = 0.538768, coord = [ 961.50195705 1158.47527998]
# Keypoint rightEar, score = 0.823440, coord = [993.26902508 893.60467604]
# Keypoint leftShoulder, score = 0.988226, coord = [1277.05655498 1290.02232437]
# Keypoint rightShoulder, score = 0.911659, coord = [1288.425428    779.11877647]
# Keypoint leftElbow, score = 0.773510, coord = [1414.11721539 1693.46983796]
# Keypoint rightElbow, score = 0.484888, coord = [1478.33254541  523.49913483]
# Keypoint leftWrist, score = 0.672752, coord = [ 976.18939102 1601.35594576]
# Keypoint rightWrist, score = 0.697066, coord = [1091.67036472  427.93127999]
# Keypoint leftHip, score = 0.992713, coord = [2051.47164906 1221.48430286]
# Keypoint rightHip, score = 0.932780, coord = [2085.32456335  897.6387183 ]
# Keypoint leftKnee, score = 0.949155, coord = [2606.31675233 1253.40455307]
# Keypoint rightKnee, score = 0.977070, coord = [2679.99783622  844.14204573]
# Keypoint leftAnkle, score = 0.893265, coord = [3061.71536788 1230.54424098]
# Keypoint rightAnkle, score = 0.934128, coord = [3129.0859292   877.42277936]
# Angle Right: 67.273344, Angle Left: 59.357706
# ./exercises\20190409_150801.jpg
# Results for image: ./exercises\20190409_150801.jpg
# Pose #0, score = 0.832078
# Keypoint nose, score = 0.998448, coord = [1503.25647049 1047.05769188]
# Keypoint leftEye, score = 0.998467, coord = [1436.07094334 1093.9579857 ]
# Keypoint rightEye, score = 0.998883, coord = [1439.64739948  971.13353181]
# Keypoint leftEar, score = 0.788977, coord = [1478.5977142 1192.2568507]
# Keypoint rightEar, score = 0.818789, coord = [1506.28802924  894.95117919]
# Keypoint leftShoulder, score = 0.971734, coord = [1802.23772737 1348.83246476]
# Keypoint rightShoulder, score = 0.639184, coord = [1847.17992723  749.86125729]
# Keypoint leftElbow, score = 0.866016, coord = [1932.48959526 1883.31913014]
# Keypoint rightElbow, score = 0.849575, coord = [1918.08523826  329.49908788]
# Keypoint leftWrist, score = 0.593434, coord = [1464.903799   1759.12600147]
# Keypoint rightWrist, score = 0.875420, coord = [1513.43243363  304.20236464]
# Keypoint leftHip, score = 0.481341, coord = [2825.03782505 1256.17439033]
# Keypoint rightHip, score = 0.937822, coord = [2805.44465268  880.87121914]
# Keypoint leftKnee, score = 0.982788, coord = [3463.19720794 1315.03940039]
# Keypoint rightKnee, score = 0.982007, coord = [3485.73311556  805.52042549]
# Keypoint leftAnkle, score = 0.741247, coord = [4006.50765436 1321.16886613]
# Keypoint rightAnkle, score = 0.621188, coord = [4059.76386316  807.73091322]
# Angle Right: 84.002829, Angle Left: 61.429631
# ./exercises\IMG_5579.jpg
# Results for image: ./exercises\IMG_5579.jpg
# Pose #0, score = 0.392863
# Keypoint nose, score = 0.998521, coord = [1854.41270443 1576.60767734]
# Keypoint leftEye, score = 0.997863, coord = [1847.37192906 1620.92416593]
# Keypoint rightEye, score = 0.992008, coord = [1852.51227172 1466.41838999]
# Keypoint leftEar, score = 0.553380, coord = [1952.81457147 1710.53747082]
# Keypoint rightEar, score = 0.833069, coord = [2016.99697503 1330.421237  ]
# Keypoint leftShoulder, score = 0.488246, coord = [2278.29254698 1839.84744822]
# Keypoint rightShoulder, score = 0.964210, coord = [2346.23782889 1230.31573639]
# Keypoint leftElbow, score = 0.077861, coord = [1994.88900338 2162.83729616]
# Keypoint rightElbow, score = 0.144010, coord = [2102.08822335  904.9277754 ]
# Keypoint leftWrist, score = 0.117298, coord = [1500.21449322 2229.9656927 ]
# Keypoint rightWrist, score = 0.004341, coord = [1521.2010909   904.77647983]
# Keypoint leftHip, score = 0.014589, coord = [3195.40406674 1739.54785304]
# Keypoint rightHip, score = 0.025407, coord = [3505.93551236 1408.41577972]
# Keypoint leftKnee, score = 0.374203, coord = [3850.46565243 1838.80641431]
# Keypoint rightKnee, score = 0.030200, coord = [4050.49812519 1474.74161947]
# Keypoint leftAnkle, score = 0.044083, coord = [4107.08153079 1843.32716953]
# Keypoint rightAnkle, score = 0.019387, coord = [4097.7888835  1482.12712628]
# Angle Right: 126.897061, Angle Left: 138.992897
# ./exercises\IMG_5580.jpg
# Results for image: ./exercises\IMG_5580.jpg
# Pose #0, score = 0.560971
# Keypoint nose, score = 0.802166, coord = [1269.81105129 1552.66862541]
# Keypoint leftEye, score = 0.949033, coord = [1230.29487629 1604.48806784]
# Keypoint rightEye, score = 0.962092, coord = [1237.99799231 1489.69818508]
# Keypoint leftEar, score = 0.576658, coord = [1348.61720006 1667.26716715]
# Keypoint rightEar, score = 0.861829, coord = [1337.58020606 1390.56937923]
# Keypoint leftShoulder, score = 0.718872, coord = [1734.23935081 1832.52614586]
# Keypoint rightShoulder, score = 0.147262, coord = [1686.52943531 1268.32723186]
# Keypoint leftElbow, score = 0.394133, coord = [2092.08874694 2212.10199872]
# Keypoint rightElbow, score = 0.422459, coord = [2072.62113378  908.32316663]
# Keypoint leftWrist, score = 0.869518, coord = [1702.6556191  2158.06456793]
# Keypoint rightWrist, score = 0.863816, coord = [1645.68336015  866.86138583]
# Keypoint leftHip, score = 0.971869, coord = [2931.60245752 1853.09596134]
# Keypoint rightHip, score = 0.340761, coord = [2904.61509282 1279.05673841]
# Keypoint leftKnee, score = 0.136638, coord = [4125.21787496 2226.41394159]
# Keypoint rightKnee, score = 0.489886, coord = [4060.3697506  1134.65817288]
# Keypoint leftAnkle, score = 0.004167, coord = [4226.69933717 2292.09511743]
# Keypoint rightAnkle, score = 0.025341, coord = [4150.4788173 1108.947459 ]
# Angle Right: 48.544286, Angle Left: 38.787721
# ./exercises\IMG_5581.jpg
# Results for image: ./exercises\IMG_5581.jpg
# Pose #0, score = 0.525117
# Keypoint nose, score = 0.999343, coord = [1731.64486162 1585.18721816]
# Keypoint leftEye, score = 0.998414, coord = [1712.60897211 1622.01518244]
# Keypoint rightEye, score = 0.997664, coord = [1717.64411314 1487.99777145]
# Keypoint leftEar, score = 0.298684, coord = [1815.72769995 1711.83833927]
# Keypoint rightEar, score = 0.958264, coord = [1849.51322948 1359.18511405]
# Keypoint leftShoulder, score = 0.981309, coord = [2205.5028841  1859.98454856]
# Keypoint rightShoulder, score = 0.976229, coord = [2183.88061295 1236.06261288]
# Keypoint leftElbow, score = 0.160324, coord = [2057.10433024 2408.87834035]
# Keypoint rightElbow, score = 0.462613, coord = [2056.11594701  679.06546364]
# Keypoint leftWrist, score = 0.838754, coord = [1551.92472668 2172.02824734]
# Keypoint rightWrist, score = 0.874738, coord = [1517.29500468  892.84572451]
# Keypoint leftHip, score = 0.243189, coord = [3368.2766028  1793.55587967]
# Keypoint rightHip, score = 0.064856, coord = [3469.07799897 1347.15848551]
# Keypoint leftKnee, score = 0.023409, coord = [4143.9900604  1714.24669695]
# Keypoint rightKnee, score = 0.032660, coord = [4164.83557418 1273.66439838]
# Keypoint leftAnkle, score = 0.007789, coord = [4029.50034785 1804.90245089]
# Keypoint rightAnkle, score = 0.008744, coord = [4035.92977601 1318.10442863]
# Angle Right: 81.278103, Angle Left: 80.009543
# ./exercises\IMG_5582.jpg
# Results for image: ./exercises\IMG_5582.jpg
# Pose #0, score = 0.652189
# Keypoint nose, score = 0.998514, coord = [1504.79750027 1616.13583564]
# Keypoint leftEye, score = 0.988762, coord = [1449.53939117 1659.65560511]
# Keypoint rightEye, score = 0.999345, coord = [1474.23515495 1523.98663609]
# Keypoint leftEar, score = 0.387597, coord = [1543.63040169 1723.8492778 ]
# Keypoint rightEar, score = 0.971339, coord = [1560.0151594  1390.87984374]
# Keypoint leftShoulder, score = 0.972053, coord = [1901.04194196 1857.55298487]
# Keypoint rightShoulder, score = 0.808405, coord = [1896.12986698 1269.57638948]
# Keypoint leftElbow, score = 0.742777, coord = [2169.3932626  2347.13058979]
# Keypoint rightElbow, score = 0.877295, coord = [2157.95251145  788.56751447]
# Keypoint leftWrist, score = 0.917228, coord = [1684.2374811  2207.88983945]
# Keypoint rightWrist, score = 0.887273, coord = [1655.3091627   872.83747089]
# Keypoint leftHip, score = 0.658925, coord = [3042.79267727 1904.1791682 ]
# Keypoint rightHip, score = 0.434751, coord = [3023.3125312  1277.14346794]
# Keypoint leftKnee, score = 0.254253, coord = [4123.24781126 2159.207536  ]
# Keypoint rightKnee, score = 0.170878, coord = [4180.79675415 1189.88837286]
# Keypoint leftAnkle, score = 0.012432, coord = [4132.9172896  2256.59086337]
# Keypoint rightAnkle, score = 0.005384, coord = [4143.7646215  1271.29887776]
# Angle Right: 51.922342, Angle Left: 45.258015
# ./exercises\IMG_5583.jpg
# Results for image: ./exercises\IMG_5583.jpg
# Pose #0, score = 0.526694
# Keypoint nose, score = 0.997661, coord = [1249.81532759 1490.14026545]
# Keypoint leftEye, score = 0.997826, coord = [1211.35374591 1561.54801814]
# Keypoint rightEye, score = 0.998350, coord = [1207.03827376 1402.74985731]
# Keypoint leftEar, score = 0.806061, coord = [1308.15854228 1641.86314199]
# Keypoint rightEar, score = 0.939288, coord = [1329.31137359 1264.92618756]
# Keypoint leftShoulder, score = 0.693415, coord = [1735.730038   1796.13635645]
# Keypoint rightShoulder, score = 0.965037, coord = [1776.43111692 1091.08589054]
# Keypoint leftElbow, score = 0.205008, coord = [2205.43660928 2236.19091924]
# Keypoint rightElbow, score = 0.675753, coord = [2240.68347868  624.44142761]
# Keypoint leftWrist, score = 0.790089, coord = [1703.46807656 2248.04707706]
# Keypoint rightWrist, score = 0.458381, coord = [1719.63486524  702.18021095]
# Keypoint leftHip, score = 0.209473, coord = [3074.45949823 1672.0429126 ]
# Keypoint rightHip, score = 0.133031, coord = [3040.26442454 1083.93908974]
# Keypoint leftKnee, score = 0.049398, coord = [4216.17514715 2013.99313048]
# Keypoint rightKnee, score = 0.027440, coord = [4197.02037722  990.69502306]
# Keypoint leftAnkle, score = 0.003085, coord = [4137.16789173 2019.66851292]
# Keypoint rightAnkle, score = 0.004496, coord = [4130.24569953  962.37814413]
# Angle Right: 36.661478, Angle Left: 44.486245
# ./exercises\IMG_5584.jpg
# Results for image: ./exercises\IMG_5584.jpg
# Pose #0, score = 0.420122
# Keypoint nose, score = 0.999576, coord = [2172.42679191 1522.67007203]
# Keypoint leftEye, score = 0.997580, coord = [2125.50292558 1587.61395454]
# Keypoint rightEye, score = 0.997771, coord = [2129.41843785 1421.56620493]
# Keypoint leftEar, score = 0.752912, coord = [2259.4033336  1699.21592426]
# Keypoint rightEar, score = 0.954250, coord = [2278.43901035 1290.81807643]
# Keypoint leftShoulder, score = 0.834314, coord = [2634.86942152 1882.02619528]
# Keypoint rightShoulder, score = 0.917104, coord = [2694.19302216 1131.4050388 ]
# Keypoint leftElbow, score = 0.010197, coord = [2379.79253526 2434.86934496]
# Keypoint rightElbow, score = 0.035344, coord = [2378.1641587   598.92976596]
# Keypoint leftWrist, score = 0.003424, coord = [1756.74602617 2215.31853757]
# Keypoint rightWrist, score = 0.006129, coord = [1798.3452672   616.18639165]
# Keypoint leftHip, score = 0.016138, coord = [3746.31601386 1844.76857813]
# Keypoint rightHip, score = 0.135723, coord = [3819.52182775 1145.57367673]
# Keypoint leftKnee, score = 0.108345, coord = [4087.66670063 1675.93409425]
# Keypoint rightKnee, score = 0.294406, coord = [4078.93410266 1144.40184585]
# Keypoint leftAnkle, score = 0.030411, coord = [4068.13983664 1656.66157148]
# Keypoint rightAnkle, score = 0.048444, coord = [4090.85825293 1164.50640426]
# Angle Right: 118.984773, Angle Left: 95.356602
# ./exercises\IMG_5585.jpg
# Results for image: ./exercises\IMG_5585.jpg
# Pose #0, score = 0.385693
# Keypoint nose, score = 0.999260, coord = [1823.58272592 1494.57018746]
# Keypoint leftEye, score = 0.996102, coord = [1765.24317576 1545.89994877]
# Keypoint rightEye, score = 0.999637, coord = [1790.81100502 1380.03125861]
# Keypoint leftEar, score = 0.254717, coord = [1880.38359713 1663.11203248]
# Keypoint rightEar, score = 0.938434, coord = [1958.34161712 1229.53952523]
# Keypoint leftShoulder, score = 0.947061, coord = [2358.08488308 1803.60337117]
# Keypoint rightShoulder, score = 0.983341, coord = [2339.90559429 1108.81776283]
# Keypoint leftElbow, score = 0.059365, coord = [2146.69196759 2401.81920447]
# Keypoint rightElbow, score = 0.019454, coord = [2258.94061629  493.78516016]
# Keypoint leftWrist, score = 0.124189, coord = [1551.39268223 2326.0693768 ]
# Keypoint rightWrist, score = 0.185382, coord = [1482.71526567  655.75230524]
# Keypoint leftHip, score = 0.013669, coord = [3233.95616199 1612.89415488]
# Keypoint rightHip, score = 0.006249, coord = [3537.38303471 1124.65417206]
# Keypoint leftKnee, score = 0.005933, coord = [4094.06019497 1676.89884719]
# Keypoint rightKnee, score = 0.008411, coord = [4073.30717731 1235.43850059]
# Keypoint leftAnkle, score = 0.008788, coord = [4005.92586065 1702.12239027]
# Keypoint rightAnkle, score = 0.006787, coord = [4050.77091489 1371.47673996]
# Angle Right: 85.713264, Angle Left: 102.210275
# ./exercises\IMG_5586.jpg
# Results for image: ./exercises\IMG_5586.jpg
# Pose #0, score = 0.522559
# Keypoint nose, score = 0.988341, coord = [1339.9931359  1533.32436488]
# Keypoint leftEye, score = 0.963120, coord = [1289.91950073 1564.85593406]
# Keypoint rightEye, score = 0.994971, coord = [1292.78608233 1432.35810973]
# Keypoint leftEar, score = 0.156004, coord = [1340.39800059 1641.29735904]
# Keypoint rightEar, score = 0.963242, coord = [1385.9465122  1242.31783609]
# Keypoint leftShoulder, score = 0.667790, coord = [1841.95493231 1831.95824488]
# Keypoint rightShoulder, score = 0.964642, coord = [1824.74824794 1099.64641151]
# Keypoint leftElbow, score = 0.672938, coord = [2248.66290449 2429.93882487]
# Keypoint rightElbow, score = 0.783693, coord = [2204.76466997  482.92564809]
# Keypoint leftWrist, score = 0.308569, coord = [1687.60656053 2118.30593249]
# Keypoint rightWrist, score = 0.742131, coord = [1561.67737577  656.17710959]
# Keypoint leftHip, score = 0.521371, coord = [3218.81422225 1774.11978553]
# Keypoint rightHip, score = 0.117248, coord = [3250.56448874 1091.85117976]
# Keypoint leftKnee, score = 0.008556, coord = [4191.01465026 1994.57029835]
# Keypoint rightKnee, score = 0.022603, coord = [4172.47098182  976.11222455]
# Keypoint leftAnkle, score = 0.002043, coord = [4115.5416555  2090.41618176]
# Keypoint rightAnkle, score = 0.006241, coord = [4096.80107562 1157.80352932]
# Angle Right: 43.281250, Angle Left: 26.729454
# ./exercises\IMG_5587.jpg
# Results for image: ./exercises\IMG_5587.jpg
# Pose #0, score = 0.527366
# Keypoint nose, score = 0.985980, coord = [1166.48030924 1496.05397096]
# Keypoint leftEye, score = 0.992585, coord = [1141.6295667  1557.36253006]
# Keypoint rightEye, score = 0.997297, coord = [1147.3661418  1404.11294938]
# Keypoint leftEar, score = 0.833422, coord = [1261.50065982 1655.39278779]
# Keypoint rightEar, score = 0.956011, coord = [1292.8499395  1268.21829187]
# Keypoint leftShoulder, score = 0.891052, coord = [1793.71440832 1821.40740486]
# Keypoint rightShoulder, score = 0.958424, coord = [1745.87979663 1098.46937661]
# Keypoint leftElbow, score = 0.192237, coord = [2191.32363519 2241.77680563]
# Keypoint rightElbow, score = 0.500930, coord = [2145.10394181  637.85956259]
# Keypoint leftWrist, score = 0.674835, coord = [1609.74022159 2268.14579219]
# Keypoint rightWrist, score = 0.475452, coord = [1664.40223279  685.88517503]
# Keypoint leftHip, score = 0.150002, coord = [3086.64917449 1693.03779079]
# Keypoint rightHip, score = 0.274682, coord = [3044.41229903 1108.73818584]
# Keypoint leftKnee, score = 0.018781, coord = [4203.90089534 2052.18697096]
# Keypoint rightKnee, score = 0.057913, coord = [4218.55335021  981.63382417]
# Keypoint leftAnkle, score = 0.002234, coord = [4115.83343156 2106.42524645]
# Keypoint rightAnkle, score = 0.003385, coord = [4099.69483952 1013.79198604]
# Angle Right: 43.378224, Angle Left: 49.189850
# ./exercises\IMG_5588.jpg
# Results for image: ./exercises\IMG_5588.jpg
# Pose #0, score = 0.482174
# Keypoint nose, score = 0.998707, coord = [1049.0435116  1556.84839556]
# Keypoint leftEye, score = 0.999203, coord = [ 938.29955971 1677.86492218]
# Keypoint rightEye, score = 0.999409, coord = [ 941.68721556 1442.84441975]
# Keypoint leftEar, score = 0.499471, coord = [ 922.27114122 1797.67597082]
# Keypoint rightEar, score = 0.936578, coord = [ 944.91621795 1252.11437244]
# Keypoint leftShoulder, score = 0.735310, coord = [1303.78044635 1928.02410883]
# Keypoint rightShoulder, score = 0.981220, coord = [1249.229045   1097.38182778]
# Keypoint leftElbow, score = 0.056328, coord = [1812.91590817 2301.79051731]
# Keypoint rightElbow, score = 0.603808, coord = [2000.41940041  791.119217  ]
# Keypoint leftWrist, score = 0.483179, coord = [2608.98254821 2475.81244087]
# Keypoint rightWrist, score = 0.857988, coord = [2663.01389623  567.10373099]
# Keypoint leftHip, score = 0.003582, coord = [2225.98315521 1636.19671565]
# Keypoint rightHip, score = 0.010303, coord = [2017.07938825 1148.58539552]
# Keypoint leftKnee, score = 0.005847, coord = [2537.20600355 1638.51620596]
# Keypoint rightKnee, score = 0.000179, coord = [2600.06927787  983.131073  ]
# Keypoint leftAnkle, score = 0.019677, coord = [2876.59691449 1644.58109352]
# Keypoint rightAnkle, score = 0.006173, coord = [3013.49969635 1013.22732572]
# Angle Right: 176.498924, Angle Left: 156.047877
# ./exercises\IMG_5589.jpg
# Results for image: ./exercises\IMG_5589.jpg
# Pose #0, score = 0.444805
# Keypoint nose, score = 0.999839, coord = [1110.12081308 1629.26870791]
# Keypoint leftEye, score = 0.999500, coord = [ 978.39219211 1727.71314493]
# Keypoint rightEye, score = 0.999884, coord = [ 985.86850877 1500.39799869]
# Keypoint leftEar, score = 0.258844, coord = [ 999.92109813 1836.79479461]
# Keypoint rightEar, score = 0.936383, coord = [1064.47286287 1316.00562488]
# Keypoint leftShoulder, score = 0.582668, coord = [1465.82363001 1977.72851679]
# Keypoint rightShoulder, score = 0.969161, coord = [1543.09846272 1136.13151718]
# Keypoint leftElbow, score = 0.091757, coord = [2105.44353289 2281.24391782]
# Keypoint rightElbow, score = 0.075678, coord = [2151.54915476  878.19172383]
# Keypoint leftWrist, score = 0.818609, coord = [2819.33991666 2537.09742848]
# Keypoint rightWrist, score = 0.595828, coord = [2829.02686628  665.2901378 ]
# Keypoint leftHip, score = 0.117680, coord = [2261.99997854 1651.70041983]
# Keypoint rightHip, score = 0.018425, coord = [2073.28232854 1228.03996628]
# Keypoint leftKnee, score = 0.003950, coord = [2508.92739221 1787.36427714]
# Keypoint rightKnee, score = 0.027781, coord = [2292.78744393  936.68848828]
# Keypoint leftAnkle, score = 0.006987, coord = [2846.64340164 1660.42004613]
# Keypoint rightAnkle, score = 0.058716, coord = [2864.51483352  647.22314056]
# Angle Right: 174.472162, Angle Left: 174.331693
# ./exercises\IMG_5590.jpg
# Results for image: ./exercises\IMG_5590.jpg
# Pose #0, score = 0.252434
# Keypoint nose, score = 0.975928, coord = [2757.19435504 1621.88366512]
# Keypoint leftEye, score = 0.970160, coord = [2609.5267372  1690.35968888]
# Keypoint rightEye, score = 0.960562, coord = [2648.39766885 1454.90395817]
# Keypoint leftEar, score = 0.858210, coord = [2475.45881482 1863.73042605]
# Keypoint rightEar, score = 0.154000, coord = [2557.0462957 1272.3591392]
# Keypoint leftShoulder, score = 0.068275, coord = [2827.23759959 1994.51961536]
# Keypoint rightShoulder, score = 0.077199, coord = [2829.24988874 1193.9814997 ]
# Keypoint leftElbow, score = 0.057429, coord = [2977.99376399 2461.03185745]
# Keypoint rightElbow, score = 0.019579, coord = [3066.02601194  984.33895277]
# Keypoint leftWrist, score = 0.044873, coord = [2993.84252656 2477.08822727]
# Keypoint rightWrist, score = 0.017528, coord = [3174.85461053 1067.32363533]
# Keypoint leftHip, score = 0.006497, coord = [3686.09328501 1998.71177062]
# Keypoint rightHip, score = 0.037296, coord = [3379.95797564 1307.76446463]
# Keypoint leftKnee, score = 0.020659, coord = [3834.3749218  2051.86646764]
# Keypoint rightKnee, score = 0.004150, coord = [3713.51551617 1177.51346653]
# Keypoint leftAnkle, score = 0.009123, coord = [3991.49815547 2010.09954165]
# Keypoint rightAnkle, score = 0.009904, coord = [4014.18643573 1176.42832948]
# Angle Right: 101.151713, Angle Left: 153.281362
# ./exercises\IMG_5591.jpg
# Results for image: ./exercises\IMG_5591.jpg
# Angle Right: 101.151713, Angle Left: 153.281362
# ./exercises\IMG_5592.jpg
# Results for image: ./exercises\IMG_5592.jpg
# Angle Right: 101.151713, Angle Left: 153.281362
# ./exercises\IMG_5595.jpg
# Results for image: ./exercises\IMG_5595.jpg
# Pose #0, score = 0.434485
# Keypoint nose, score = 0.978789, coord = [1126.86633746 1653.58324582]
# Keypoint leftEye, score = 0.951491, coord = [1110.27192715 1684.54849132]
# Keypoint rightEye, score = 0.991598, coord = [1096.47401854 1545.59710816]
# Keypoint leftEar, score = 0.139932, coord = [1216.64509716 1730.39747245]
# Keypoint rightEar, score = 0.644324, coord = [1266.24034259 1381.55308554]
# Keypoint leftShoulder, score = 0.201632, coord = [1698.79346997 1918.77831968]
# Keypoint rightShoulder, score = 0.931443, coord = [1689.97515534 1268.62120618]
# Keypoint leftElbow, score = 0.910785, coord = [1811.78260541 2552.76317553]
# Keypoint rightElbow, score = 0.363718, coord = [1756.8098318  637.3418257]
# Keypoint leftWrist, score = 0.550957, coord = [1264.12753608 2374.40534398]
# Keypoint rightWrist, score = 0.251420, coord = [1218.7325406   840.19782746]
# Keypoint leftHip, score = 0.101683, coord = [2889.88520627 2004.04184087]
# Keypoint rightHip, score = 0.131498, coord = [2923.1657517  1318.53859946]
# Keypoint leftKnee, score = 0.083991, coord = [4197.09475    2199.32772933]
# Keypoint rightKnee, score = 0.144248, coord = [4191.19726441 1063.7046861 ]
# Keypoint leftAnkle, score = 0.003397, coord = [4174.71094892 2274.42195119]
# Keypoint rightAnkle, score = 0.005338, coord = [4131.97621882 1113.94287706]
# Angle Right: 63.299983, Angle Left: 61.855652
# ./exercises\IMG_5596.jpg
# Results for image: ./exercises\IMG_5596.jpg
# Pose #0, score = 0.368077
# Keypoint nose, score = 0.409773, coord = [1158.02197768 1595.45383203]
# Keypoint leftEye, score = 0.604268, coord = [1069.24561833 1638.72102103]
# Keypoint rightEye, score = 0.823786, coord = [1054.04684091 1552.4246106 ]
# Keypoint leftEar, score = 0.364860, coord = [1158.38837343 1666.25708476]
# Keypoint rightEar, score = 0.891581, coord = [1142.05074717 1398.29514764]
# Keypoint leftShoulder, score = 0.080457, coord = [1494.62765495 1592.18466429]
# Keypoint rightShoulder, score = 0.946497, coord = [1509.8061563  1248.31157138]
# Keypoint leftElbow, score = 0.197092, coord = [1907.67296222 2186.35883086]
# Keypoint rightElbow, score = 0.039113, coord = [1903.19721604  955.65197025]
# Keypoint leftWrist, score = 0.774226, coord = [1450.24052768 2302.2194966 ]
# Keypoint rightWrist, score = 0.276169, coord = [1468.78792627  798.45944441]
# Keypoint leftHip, score = 0.090558, coord = [2634.82672621 1773.66115884]
# Keypoint rightHip, score = 0.399003, coord = [2719.42492402 1230.77701249]
# Keypoint leftKnee, score = 0.054039, coord = [4017.72554606 1982.9995679 ]
# Keypoint rightKnee, score = 0.296675, coord = [3978.84626233 1073.6579715 ]
# Keypoint leftAnkle, score = 0.002471, coord = [4165.85741366 2097.70908907]
# Keypoint rightAnkle, score = 0.006747, coord = [4128.87132769 1118.2600571 ]
# Angle Right: 56.539893, Angle Left: 69.407809
# ./exercises\IMG_5597.jpg
# Results for image: ./exercises\IMG_5597.jpg
# Pose #0, score = 0.458422
# Keypoint nose, score = 0.950260, coord = [1323.01861957 1613.16334154]
# Keypoint leftEye, score = 0.960838, coord = [1277.49209688 1651.11959364]
# Keypoint rightEye, score = 0.985725, coord = [1263.31812315 1499.75241548]
# Keypoint leftEar, score = 0.143047, coord = [1376.59366476 1762.9835128 ]
# Keypoint rightEar, score = 0.892056, coord = [1409.03211773 1343.85266735]
# Keypoint leftShoulder, score = 0.535729, coord = [1890.92708034 1864.988667  ]
# Keypoint rightShoulder, score = 0.963834, coord = [1840.9310216  1173.77528061]
# Keypoint leftElbow, score = 0.677969, coord = [2104.30333799 2511.636365  ]
# Keypoint rightElbow, score = 0.162484, coord = [2078.56891402  620.5824302 ]
# Keypoint leftWrist, score = 0.162414, coord = [1575.68928113 2212.85047844]
# Keypoint rightWrist, score = 0.806951, coord = [1469.35022901  730.07614862]
# Keypoint leftHip, score = 0.232058, coord = [3126.73280635 1889.09629801]
# Keypoint rightHip, score = 0.247974, coord = [3314.91450436 1212.81194754]
# Keypoint leftKnee, score = 0.019925, coord = [4223.33002759 1970.50080682]
# Keypoint rightKnee, score = 0.042040, coord = [4215.19234476 1262.69267323]
# Keypoint leftAnkle, score = 0.004035, coord = [4114.4821406  1998.57271982]
# Keypoint rightAnkle, score = 0.005843, coord = [4114.37016909 1285.94849269]
# Angle Right: 56.563959, Angle Left: 42.262287
# ./exercises\IMG_5598.jpg
# Results for image: ./exercises\IMG_5598.jpg
# Pose #0, score = 0.367932
# Keypoint nose, score = 0.997817, coord = [2240.31533292 1588.54029374]
# Keypoint leftEye, score = 0.998786, coord = [2198.93350714 1647.19708532]
# Keypoint rightEye, score = 0.999261, coord = [2199.67130894 1484.22183617]
# Keypoint leftEar, score = 0.529916, coord = [2331.62614194 1755.2504448 ]
# Keypoint rightEar, score = 0.827363, coord = [2357.11841566 1355.53455406]
# Keypoint leftShoulder, score = 0.921809, coord = [2716.56106721 1913.93517512]
# Keypoint rightShoulder, score = 0.620696, coord = [2731.29813029 1261.88190003]
# Keypoint leftElbow, score = 0.020214, coord = [2433.79787774 2344.64660709]
# Keypoint rightElbow, score = 0.030286, coord = [2609.55940715  902.49595476]
# Keypoint leftWrist, score = 0.041018, coord = [1931.34750891 2284.93278942]
# Keypoint rightWrist, score = 0.010924, coord = [2004.40329231  818.1486005 ]
# Keypoint leftHip, score = 0.040533, coord = [3826.40541678 1859.44183814]
# Keypoint rightHip, score = 0.043104, coord = [3964.60976671 1269.48928838]
# Keypoint leftKnee, score = 0.075711, coord = [4083.82090565 1775.13482745]
# Keypoint rightKnee, score = 0.061365, coord = [4107.63629653 1334.50107627]
# Keypoint leftAnkle, score = 0.024084, coord = [4057.10967725 1670.31175716]
# Keypoint rightAnkle, score = 0.011962, coord = [4074.61219624 1314.15757671]
# Angle Right: 116.648175, Angle Left: 116.507465
# ./exercises\IMG_5599.jpg
# Results for image: ./exercises\IMG_5599.jpg
# Pose #0, score = 0.472118
# Keypoint nose, score = 0.975713, coord = [1082.30360835 1551.25123298]
# Keypoint leftEye, score = 0.957791, coord = [1078.07946245 1610.99598253]
# Keypoint rightEye, score = 0.949909, coord = [1044.13345991 1479.83496078]
# Keypoint leftEar, score = 0.717968, coord = [1185.85463998 1679.57764825]
# Keypoint rightEar, score = 0.793908, coord = [1142.85268063 1333.69301297]
# Keypoint leftShoulder, score = 0.418736, coord = [1598.65688364 1859.66985672]
# Keypoint rightShoulder, score = 0.308819, coord = [1586.66499142 1199.98420604]
# Keypoint leftElbow, score = 0.440937, coord = [2062.80010986 2343.52702807]
# Keypoint rightElbow, score = 0.271101, coord = [1898.30762263  731.89668987]
# Keypoint leftWrist, score = 0.605357, coord = [1490.27322243 2322.70609777]
# Keypoint rightWrist, score = 0.716210, coord = [1485.97568183  747.58405877]
# Keypoint leftHip, score = 0.734280, coord = [2900.85708093 1744.88949511]
# Keypoint rightHip, score = 0.087391, coord = [2855.95440719 1227.033147  ]
# Keypoint leftKnee, score = 0.006816, coord = [4127.04888764 2073.06032058]
# Keypoint rightKnee, score = 0.033530, coord = [4165.64538026 1173.39219411]
# Keypoint leftAnkle, score = 0.001419, coord = [4137.15690267 2073.70421611]
# Keypoint rightAnkle, score = 0.006123, coord = [4116.48035779 1160.38226477]
# Angle Right: 54.166380, Angle Left: 44.108569
# ./exercises\IMG_5600.jpg
# Results for image: ./exercises\IMG_5600.jpg
# Pose #0, score = 0.311404
# Keypoint nose, score = 0.969169, coord = [2471.19254415 1531.18364463]
# Keypoint leftEye, score = 0.966613, coord = [2400.79017955 1627.87215149]
# Keypoint rightEye, score = 0.864104, coord = [2360.96829079 1441.92247627]
# Keypoint leftEar, score = 0.983606, coord = [2278.49418583 1808.81226102]
# Keypoint rightEar, score = 0.205342, coord = [2253.53143463 1279.18810106]
# Keypoint leftShoulder, score = 0.093001, coord = [2509.03268973 1807.91327158]
# Keypoint rightShoulder, score = 0.073655, coord = [2445.23014257 1225.12438701]
# Keypoint leftElbow, score = 0.004747, coord = [2639.4047949  2178.95841552]
# Keypoint rightElbow, score = 0.007507, coord = [2373.21108088  824.03411802]
# Keypoint leftWrist, score = 0.876060, coord = [2813.03063348 2545.10156915]
# Keypoint rightWrist, score = 0.037073, coord = [2643.83076184  612.67261038]
# Keypoint leftHip, score = 0.055395, coord = [3044.99983539 1723.31616338]
# Keypoint rightHip, score = 0.017139, coord = [2857.23257435 1221.70483678]
# Keypoint leftKnee, score = 0.047122, coord = [3374.22252157 1851.12828386]
# Keypoint rightKnee, score = 0.050185, coord = [3104.8362544  1259.22010993]
# Keypoint leftAnkle, score = 0.022580, coord = [3648.53437231 1801.36599998]
# Keypoint rightAnkle, score = 0.020562, coord = [3487.06316674 1210.84069699]
# Angle Right: 117.811373, Angle Left: 173.989262
# ./exercises\IMG_5601.jpg
# Results for image: ./exercises\IMG_5601.jpg
# Pose #0, score = 0.266860
# Keypoint nose, score = 0.995302, coord = [3080.71325353 1502.5739059 ]
# Keypoint leftEye, score = 0.984597, coord = [2988.20522105 1600.4526529 ]
# Keypoint rightEye, score = 0.923093, coord = [2957.65917954 1437.63769782]
# Keypoint leftEar, score = 0.960779, coord = [2870.85469143 1829.97057524]
# Keypoint rightEar, score = 0.160474, coord = [2788.52471969 1290.12785371]
# Keypoint leftShoulder, score = 0.067049, coord = [3163.27478438 1840.89697234]
# Keypoint rightShoulder, score = 0.101772, coord = [3027.80904489 1272.06458111]
# Keypoint leftElbow, score = 0.006981, coord = [3352.86850809 2090.65158474]
# Keypoint rightElbow, score = 0.062534, coord = [3124.23286054  953.10088641]
# Keypoint leftWrist, score = 0.007332, coord = [3276.75457307 2184.43864187]
# Keypoint rightWrist, score = 0.202856, coord = [2872.3215402   623.11145062]
# Keypoint leftHip, score = 0.004439, coord = [3607.9812167  1826.23028221]
# Keypoint rightHip, score = 0.003451, coord = [3450.94373563 1299.00363657]
# Keypoint leftKnee, score = 0.005932, coord = [3894.01627527 1867.591297  ]
# Keypoint rightKnee, score = 0.035066, coord = [3509.10949989  992.59397002]
# Keypoint leftAnkle, score = 0.007531, coord = [3983.07975518 1831.26855853]
# Keypoint rightAnkle, score = 0.007432, coord = [3856.71510164 1031.91100781]
# Angle Right: 125.821926, Angle Left: 103.735696
# ./exercises\IMG_5603.jpg
# Results for image: ./exercises\IMG_5603.jpg
# Pose #0, score = 0.356546
# Keypoint nose, score = 0.979158, coord = [2370.73566869 1601.34786781]
# Keypoint leftEye, score = 0.997692, coord = [2226.82130657 1686.57036312]
# Keypoint rightEye, score = 0.993358, coord = [2200.72197314 1435.82305412]
# Keypoint leftEar, score = 0.731280, coord = [2109.53418943 1837.34666444]
# Keypoint rightEar, score = 0.516326, coord = [2109.45903034 1219.34102755]
# Keypoint leftShoulder, score = 0.079538, coord = [2301.42120742 1950.3933701 ]
# Keypoint rightShoulder, score = 0.008221, coord = [2399.14955775 1110.98942276]
# Keypoint leftElbow, score = 0.292361, coord = [2346.20631443 2652.64584847]
# Keypoint rightElbow, score = 0.008190, coord = [2299.2730652   499.24880464]
# Keypoint leftWrist, score = 0.494409, coord = [2931.26120429 2469.15799056]
# Keypoint rightWrist, score = 0.917363, coord = [2883.56231142  555.52939814]
# Keypoint leftHip, score = 0.020255, coord = [2806.1145639 1884.5854319]
# Keypoint rightHip, score = 0.006532, coord = [3020.21017878 1058.85893205]
# Keypoint leftKnee, score = 0.005408, coord = [3079.53578353 2224.52842752]
# Keypoint rightKnee, score = 0.005272, coord = [3513.45371047 1036.80212858]
# Keypoint leftAnkle, score = 0.003056, coord = [3484.4026904  2138.52501348]
# Keypoint rightAnkle, score = 0.002872, coord = [3824.69460782 1228.38389015]
# Angle Right: 75.225418, Angle Left: 76.236281
# ./exercises\IMG_5604.jpg
# Results for image: ./exercises\IMG_5604.jpg
# Angle Right: 75.225418, Angle Left: 76.236281
# Average FPS: 1.086294290973054

# %%
with tf.Session() as sess:
        model_cfg, model_outputs = posenet.load_model(model_number, sess)
        output_stride = model_cfg['output_stride']
        #cap = cv2.VideoCapture(args.cam_id)
        cap = cv2.VideoCapture("IMG_5593.avi")
        #cap.set(3, args.cam_width)
        #cap.set(4, args.cam_height)
        cap.set(3, 1080)
        cap.set(4, 1920)

        start = time.time()
        frame_count = 0
        min = 10000
        prev = 10000
        state = 0
        while True:
            input_image, display_image, output_scale = posenet.read_cap(
                cap, scale_factor=0.2, output_stride=output_stride)
            #output_stride
            #args.scale_factor
            heatmaps_result, offsets_result, displacement_fwd_result, displacement_bwd_result = sess.run(
                model_outputs,
                feed_dict={'image:0': input_image}
            )

            pose_scores, keypoint_scores, keypoint_coords = posenet.decode_multi.decode_multiple_poses(
                heatmaps_result.squeeze(axis=0),
                offsets_result.squeeze(axis=0),
                displacement_fwd_result.squeeze(axis=0),
                displacement_bwd_result.squeeze(axis=0),
                output_stride=output_stride,
                max_pose_detections=10,
                min_pose_score=0.15)

            keypoint_coords *= output_scale

            # TODO this isn't particularly fast, use GL for drawing and display someday...
            overlay_image = posenet.draw_skel_and_kp(
                display_image, pose_scores, keypoint_scores, keypoint_coords,
                min_pose_score=0.15, min_part_score=0.1)

            overlay_image = cv2.resize(overlay_image, (600, 900))

            for pi in range(len(pose_scores)):
                if pose_scores[pi] == 0.:
                    break
                #logging.warning('Pose #%d, score = %f' % (pi, pose_scores[pi]))
                for ki, (s, c) in enumerate(zip(keypoint_scores[pi, :], keypoint_coords[pi, :, :])):
                	if posenet.PART_NAMES[ki] == "leftEye":
                	    logging.warning('Keypoint %s, score = %f, coord = %s' % (posenet.PART_NAMES[ki], s, c))
                	    if c[0] > prev and state == 0:
                	    	prev = c[0]
                	    elif c[0] < prev and state == 0:
                	    	state = 1
                	    elif c[0] < min and state == 1:
                	    	min = c[0]
                	    elif c[0] > min and state == 1:
                	    	logging.warning('FOUND MAX')
                	    	prev = c[0]
                	    	min = 10000
                	    	state = 0

            cv2.imshow('posenet', overlay_image)
            frame_count += 1
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        print('Average FPS: ', frame_count / (time.time() - start))
# Out:
# C:\Users\micha\Desktop\ML\113dbspring19\posenet-python-master\posenet-python-master\posenet\converter\config.py:9: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(cfg_f)
# Cannot find model file ./_models\model-mobilenet_v1_075.pb, converting from tfjs...
